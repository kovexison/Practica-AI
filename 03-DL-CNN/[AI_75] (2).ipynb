# %% [markdown]
# # 🧠 Introduction to CNNs for Image Classification
#
# Until now, you've learned how to apply machine learning to structured datasets (like predicting prices or classifying data based on features). But how can we teach a machine to recognize images, like telling the difference between a **headlight**, a **bumper**, or a **wheel**?
#
# That’s where **Convolutional Neural Networks (CNNs)** come in. CNNs are the **go-to architecture** in deep learning when it comes to visual understanding.
#
# ---

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os

print("Current folder:", os.getcwd())
print("Files available:", os.listdir("/content"))
# Out:
# Current folder: /content
# Files available: ['.config', 'drive', 'dataset', 'sample_data']

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['1000239834.jpeg', 'Untitled spreadsheet.gsheet', 'Cap3.zip', 'Colab Notebooks', 'ColabDatasets', 'internet_images']

# %%
print(os.listdir("/content/drive/MyDrive/ColabDatasets"))
# Out:
# ['dataset.zip']

# %%
import os
import zipfile

zip_path = "/content/drive/MyDrive/ColabDatasets/dataset.zip"
extract_path = "/content"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully.")
# Out:
# Dataset extracted successfully.

# %%
print(os.listdir("/content"))
# Out:
# ['.config', 'drive', 'dataset', 'sample_data']

# %%
print(os.listdir("/content/dataset"))
# Out:
# ['train', 'valid', '.ipynb_checkpoints', 'car parts.csv', 'test']

# %%
print(os.listdir("/content/dataset/train"))
# Out:
# ['WINDOW REGULATOR', 'ENGINE BLOCK', 'CYLINDER HEAD', 'LEAF SPRING', 'OIL PRESSURE SENSOR', 'FUSE BOX', 'CARBERATOR', 'OIL FILTER', 'ENGINE VALVE', 'SHIFT KNOB', 'CAMSHAFT', 'OVERFLOW TANK', 'BRAKE ROTOR', 'TAILLIGHTS', 'WATER PUMP', 'THERMOSTAT', 'COIL SPRING', 'HEADLIGHTS', 'SPOILER', 'BATTERY', 'AIR COMPRESSOR', 'RADIO', 'GAS CAP', 'IDLER ARM', 'MUFFLER', 'TORQUE CONVERTER', 'OXYGEN SENSOR', 'VACUUM BRAKE BOOSTER', 'SPARK PLUG', 'OIL PAN', 'RADIATOR HOSE', 'TRANSMISSION', 'CRANKSHAFT', 'BRAKE PAD', 'INSTRUMENT CLUSTER', 'RADIATOR', 'FUEL INJECTOR', 'DISTRIBUTOR', 'BRAKE CALIPER', 'RIM', 'VALVE LIFTER', 'STARTER', 'PRESSURE PLATE', 'CLUTCH PLATE', 'ALTERNATOR', 'PISTON', 'RADIATOR FAN', 'SIDE MIRROR', 'LOWER CONTROL ARM', 'IGNITION COIL']

# %%
import os

for root, dirs, files in os.walk("/content"):
    level = root.replace("/content", "").count(os.sep)

    if level <= 3:
        indent = "    " * level
        print(f"{indent}{os.path.basename(root)}/")

        for folder in dirs[:10]:
            print(f"{indent}    {folder}/")
# Out:
# content/
#     .config/
#     drive/
#     dataset/
#     sample_data/
#     .config/
#         logs/
#         configurations/
#         logs/
#             2026.06.04/
#             2026.06.04/
#         configurations/
#     drive/
#         MyDrive/
#         .shortcut-targets-by-id/
#         .Trash-0/
#         .Encrypted/
#         MyDrive/
#             Colab Notebooks/
#             ColabDatasets/
#             internet_images/
#             Colab Notebooks/
#             ColabDatasets/
#             internet_images/
#         .shortcut-targets-by-id/
#         .Trash-0/
#             files/
#             info/
#             files/
#             info/
#         .Encrypted/
#             MyDrive/
#             .shortcut-targets-by-id/
#             MyDrive/
#                 Colab Notebooks/
#                 ColabDatasets/
#                 internet_images/
#             .shortcut-targets-by-id/
#     dataset/
#         train/
#         valid/
#         .ipynb_checkpoints/
#         test/
#         train/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             CAMSHAFT/
#             OVERFLOW TANK/
#             BRAKE ROTOR/
#             TAILLIGHTS/
#             WATER PUMP/
#             THERMOSTAT/
#             COIL SPRING/
#             HEADLIGHTS/
#             SPOILER/
#             BATTERY/
#             AIR COMPRESSOR/
#             RADIO/
#             GAS CAP/
#             IDLER ARM/
#             MUFFLER/
#             TORQUE CONVERTER/
#             OXYGEN SENSOR/
#             VACUUM BRAKE BOOSTER/
#             SPARK PLUG/
#             OIL PAN/
#             RADIATOR HOSE/
#             TRANSMISSION/
#             CRANKSHAFT/
#             BRAKE PAD/
#             INSTRUMENT CLUSTER/
#             RADIATOR/
#             FUEL INJECTOR/
#             DISTRIBUTOR/
#             BRAKE CALIPER/
#             RIM/
#             VALVE LIFTER/
#             STARTER/
#             PRESSURE PLATE/
#             CLUTCH PLATE/
#             ALTERNATOR/
#             PISTON/
#             RADIATOR FAN/
#             SIDE MIRROR/
#             LOWER CONTROL ARM/
#             IGNITION COIL/
#         valid/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             CAMSHAFT/
#             OVERFLOW TANK/
#             BRAKE ROTOR/
#             TAILLIGHTS/
#             WATER PUMP/
#             THERMOSTAT/
#             COIL SPRING/
#             HEADLIGHTS/
#             SPOILER/
#             BATTERY/
#             AIR COMPRESSOR/
#             RADIO/
#             GAS CAP/
#             IDLER ARM/
#             MUFFLER/
#             TORQUE CONVERTER/
#             OXYGEN SENSOR/
#             VACUUM BRAKE BOOSTER/
#             SPARK PLUG/
#             OIL PAN/
#             RADIATOR HOSE/
#             TRANSMISSION/
#             CRANKSHAFT/
#             BRAKE PAD/
#             INSTRUMENT CLUSTER/
#             RADIATOR/
#             FUEL INJECTOR/
#             DISTRIBUTOR/
#             BRAKE CALIPER/
#             RIM/
#             VALVE LIFTER/
#             STARTER/
#             PRESSURE PLATE/
#             CLUTCH PLATE/
#             ALTERNATOR/
#             PISTON/
#             RADIATOR FAN/
#             SIDE MIRROR/
#             LOWER CONTROL ARM/
#             IGNITION COIL/
#         .ipynb_checkpoints/
#         test/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             WINDOW REGULATOR/
#             ENGINE BLOCK/
#             CYLINDER HEAD/
#             LEAF SPRING/
#             OIL PRESSURE SENSOR/
#             FUSE BOX/
#             CARBERATOR/
#             OIL FILTER/
#             ENGINE VALVE/
#             SHIFT KNOB/
#             CAMSHAFT/
#             OVERFLOW TANK/
#             BRAKE ROTOR/
#             TAILLIGHTS/
#             WATER PUMP/
#             THERMOSTAT/
#             COIL SPRING/
#             HEADLIGHTS/
#             SPOILER/
#             BATTERY/
#             AIR COMPRESSOR/
#             RADIO/
#             GAS CAP/
#             IDLER ARM/
#             MUFFLER/
#             TORQUE CONVERTER/
#             OXYGEN SENSOR/
#             VACUUM BRAKE BOOSTER/
#             SPARK PLUG/
#             OIL PAN/
#             RADIATOR HOSE/
#             TRANSMISSION/
#             CRANKSHAFT/
#             BRAKE PAD/
#             INSTRUMENT CLUSTER/
#             RADIATOR/
#             FUEL INJECTOR/
#             DISTRIBUTOR/
#             BRAKE CALIPER/
#             RIM/
#             VALVE LIFTER/
#             STARTER/
#             PRESSURE PLATE/
#             CLUTCH PLATE/
#             ALTERNATOR/
#             PISTON/
#             RADIATOR FAN/
#             SIDE MIRROR/
#             LOWER CONTROL ARM/
#             IGNITION COIL/
#     sample_data/

# %%
train_dir = "/content/dataset/train"

print("Folder exists:", os.path.exists(train_dir))

if os.path.exists(train_dir):
    class_names = sorted(
        folder
        for folder in os.listdir(train_dir)
        if os.path.isdir(os.path.join(train_dir, folder))
    )

    print("Number of classes:", len(class_names))
    print("Classes:", class_names)
# Out:
# Folder exists: True
# Number of classes: 50
# Classes: ['AIR COMPRESSOR', 'ALTERNATOR', 'BATTERY', 'BRAKE CALIPER', 'BRAKE PAD', 'BRAKE ROTOR', 'CAMSHAFT', 'CARBERATOR', 'CLUTCH PLATE', 'COIL SPRING', 'CRANKSHAFT', 'CYLINDER HEAD', 'DISTRIBUTOR', 'ENGINE BLOCK', 'ENGINE VALVE', 'FUEL INJECTOR', 'FUSE BOX', 'GAS CAP', 'HEADLIGHTS', 'IDLER ARM', 'IGNITION COIL', 'INSTRUMENT CLUSTER', 'LEAF SPRING', 'LOWER CONTROL ARM', 'MUFFLER', 'OIL FILTER', 'OIL PAN', 'OIL PRESSURE SENSOR', 'OVERFLOW TANK', 'OXYGEN SENSOR', 'PISTON', 'PRESSURE PLATE', 'RADIATOR', 'RADIATOR FAN', 'RADIATOR HOSE', 'RADIO', 'RIM', 'SHIFT KNOB', 'SIDE MIRROR', 'SPARK PLUG', 'SPOILER', 'STARTER', 'TAILLIGHTS', 'THERMOSTAT', 'TORQUE CONVERTER', 'TRANSMISSION', 'VACUUM BRAKE BOOSTER', 'VALVE LIFTER', 'WATER PUMP', 'WINDOW REGULATOR']

# %%
from pathlib import Path

dataset_dir = Path("/content/dataset")

train_dir = dataset_dir / "train"
valid_dir = dataset_dir / "valid"
test_dir = dataset_dir / "test"

image_extensions = {
    ".jpg", ".jpeg", ".png",
    ".bmp", ".gif", ".webp"
}


def get_classes(directory):
    return sorted([
        folder.name
        for folder in directory.iterdir()
        if folder.is_dir() and not folder.name.startswith(".")
    ])


def count_images(directory):
    return sum(
        1
        for file in directory.rglob("*")
        if file.is_file()
        and file.suffix.lower() in image_extensions
    )


train_classes = get_classes(train_dir)
valid_classes = get_classes(valid_dir)
test_classes = get_classes(test_dir)

print("Train folder exists:", train_dir.exists())
print("Validation folder exists:", valid_dir.exists())
print("Test folder exists:", test_dir.exists())

print("\nNumber of train classes:", len(train_classes))
print("Number of validation classes:", len(valid_classes))
print("Number of test classes:", len(test_classes))

print("\nTrain images:", count_images(train_dir))
print("Validation images:", count_images(valid_dir))
print("Test images:", count_images(test_dir))

print("\nTrain and validation classes match:",
      train_classes == valid_classes)

print("Train and test classes match:",
      train_classes == test_classes)
# Out:
# Train folder exists: True
# Validation folder exists: True
# Test folder exists: True
#
# Number of train classes: 50
# Number of validation classes: 50
# Number of test classes: 50
#
# Train images: 8739
# Validation images: 250
# Test images: 250
#
# Train and validation classes match: True
# Train and test classes match: True

# %% [markdown]
# ## 🧩 The Challenge with Image Data
#
# Images are not like tabular data. A single color image of size 128×128 has **49,152 features** (128 × 128 × 3), which:
# - Makes them **high-dimensional**
# - Contains **spatial relationships** (e.g. a tire is round, and a headlight has glassy edges)
# - Makes flattening them (as we did in ML) **lose important context**
#
# Traditional ML methods treat all pixels independently. But CNNs understand **space** — they "look" at nearby pixels together, like how our eyes and brains work.
#
# ---

# %% [markdown]
# ## 👁️ What is a CNN?
#
# CNNs (Convolutional Neural Networks) are **neural networks designed specifically for images**. They learn patterns from raw pixel data through **filters** that scan the image.

# %% [markdown]
# ![How a CNN Works](./images_gifs/cnnimage.png)

# %% [markdown]
# ### Think of CNNs as layers of virtual eyes:
# 1. **Early layers** detect **edges**, **lines**, and **color patterns**
# 2. **Middle layers** detect **shapes**, **textures**, or **symmetry**
# 3. **Later layers** detect **parts**, **objects**, or **combinations**
#
# All this happens without us manually designing the features. CNNs learn them during training.
#
# ---

# %% [markdown]
# ![Digits](images_gifs/cnndigits.gif)

# %% [markdown]
# ### 💡 How a CNN Works (Layer Ideas)
#
# **Convolution Layer**
# ➤ Learns small visual patterns (like edges, curves, textures)
# ➤ Uses filters that slide over the image
#
# **Activation (ReLU)**
# ➤ Keeps only useful signals (sets negatives to 0)
# ➤ Adds non-linearity so it can learn complex patterns
#
# **Pooling Layer**
# ➤ Shrinks the feature maps (like zooming out)
# ➤ Keeps the strongest features (e.g., max pooling)
#
# **More Conv + Pool Layers**
# ➤ Deeper layers learn higher-level parts (like car lights, tires)
# ➤ Each layer builds on the previous ones
#
# **Flatten Layer**
# ➤ Turns 2D feature maps into a 1D vector
# ➤ Prepares data for the final decision
#
# **Fully Connected (Dense) Layers**
# ➤ Combine all features to predict the class
# ➤ Similar to layers in traditional neural networks
#
# **Softmax Output**
# ➤ Outputs class probabilities
# ➤ The highest value is the model’s prediction

# %% [markdown]
# ![convs](images_gifs/convolutions.gif)

# %% [markdown]
# ### Your Challenge:

# %% [markdown]
# In this notebook, we’ll train a CNN to recognize different **car parts** from images. These might include parts like:
# - air compressor
# - battery
# - brake caliper
# - coil spring
# - oil pan and so on
#
# **Total of 50 car parts**

# %% [markdown]
# You don’t need to **tell** the model what a headlight looks like — it will **learn** the patterns by itself from labeled training images.

# %% [markdown]
# By the end of this notebook, you'll be able to:
#
# ✅ Load and preprocess image data
# ✅ Build your own CNN using TensorFlow/Keras
# ✅ Train and evaluate the model
# ✅ Visualize performance with graphs and confusion matrices
# ✅ Experiment with changes and improve accuracy

# %% [markdown]
# ## 🖼️ Let's Look at Some Examples!
#
# Before we start coding, here are some sample images from our dataset (randomly picked from different classes):

# %%
import matplotlib.pyplot as plt
import os
import random
from tensorflow.keras.preprocessing import image
from PIL import Image

dataset_path = './dataset/train'

class_dirs = [d for d in os.listdir(dataset_path)
              if os.path.isdir(os.path.join(dataset_path, d)) and not d.startswith('.')]

sampled_classes = random.sample(class_dirs, min(5, len(class_dirs)))

plt.figure(figsize=(15, 6))

for i, class_name in enumerate(sampled_classes):
    class_folder = os.path.join(dataset_path, class_name)

    valid_extensions = ['.jpg', '.jpeg', '.png']
    images_in_class = [f for f in os.listdir(class_folder)
                       if f.lower().endswith(tuple(valid_extensions)) and not f.startswith('.')]

    if not images_in_class:
        continue

    sample_image = random.choice(images_in_class)
    img_path = os.path.join(class_folder, sample_image)

    img = image.load_img(img_path, target_size=(224, 224))
    ax = plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(class_name.title(), fontsize=10)
    plt.axis("off")

plt.suptitle("Sample Images from Different Car Part Classes", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('./dataset/car parts.csv')
df.head(20)
# Out:
#     class index                     filepaths          labels data set
# 0             0  train/AIR COMPRESSOR/001.jpg  AIR COMPRESSOR    train
# 1             0  train/AIR COMPRESSOR/002.jpg  AIR COMPRESSOR    train
# 2             0  train/AIR COMPRESSOR/003.jpg  AIR COMPRESSOR    train
# 3             0  train/AIR COMPRESSOR/004.jpg  AIR COMPRESSOR    train
# 4             0  train/AIR COMPRESSOR/005.jpg  AIR COMPRESSOR    train
# 5             0  train/AIR COMPRESSOR/006.jpg  AIR COMPRESSOR    train
# 6             0  train/AIR COMPRESSOR/007.jpg  AIR COMPRESSOR    train
# 7             0  train/AIR COMPRESSOR/008.jpg  AIR COMPRESSOR    train
# 8             0  train/AIR COMPRESSOR/009.jpg  AIR COMPRESSOR    train
# 9             0  train/AIR COMPRESSOR/010.jpg  AIR COMPRESSOR    train
# 10            0  train/AIR COMPRESSOR/011.jpg  AIR COMPRESSOR    train
# 11            0  train/AIR COMPRESSOR/012.jpg  AIR COMPRESSOR    train
# 12            0  train/AIR COMPRESSOR/013.jpg  AIR COMPRESSOR    train
# 13            0  train/AIR COMPRESSOR/014.jpg  AIR COMPRESSOR    train
# 14            0  train/AIR COMPRESSOR/015.jpg  AIR COMPRESSOR    train
# 15            0  train/AIR COMPRESSOR/016.jpg  AIR COMPRESSOR    train
# 16            0  train/AIR COMPRESSOR/017.jpg  AIR COMPRESSOR    train
# 17            0  train/AIR COMPRESSOR/018.jpg  AIR COMPRESSOR    train
# 18            0  train/AIR COMPRESSOR/019.jpg  AIR COMPRESSOR    train
# 19            0  train/AIR COMPRESSOR/020.jpg  AIR COMPRESSOR    train

# %%
label_counts = df['labels'].value_counts().sort_values(ascending=False)
label_counts
# Out:
# labels
# IGNITION COIL           210
# IDLER ARM               208
# STARTER                 205
# CARBERATOR              202
# ALTERNATOR              200
# OVERFLOW TANK           199
# SHIFT KNOB              199
# RADIO                   199
# FUEL INJECTOR           198
# BRAKE PAD               198
# ENGINE BLOCK            198
# OIL PRESSURE SENSOR     197
# OIL PAN                 197
# TORQUE CONVERTER        197
# SIDE MIRROR             196
# GAS CAP                 196
# AIR COMPRESSOR          195
# SPOILER                 195
# CYLINDER HEAD           194
# OXYGEN SENSOR           192
# PRESSURE PLATE          192
# THERMOSTAT              192
# CLUTCH PLATE            191
# CRANKSHAFT              190
# INSTRUMENT CLUSTER      190
# RIM                     189
# WINDOW REGULATOR        189
# VACUUM BRAKE BOOSTER    188
# BATTERY                 187
# WATER PUMP              186
# BRAKE ROTOR             186
# RADIATOR HOSE           185
# VALVE LIFTER            185
# BRAKE CALIPER           184
# RADIATOR                179
# OIL FILTER              179
# LOWER CONTROL ARM       179
# ENGINE VALVE            176
# FUSE BOX                176
# TRANSMISSION            174
# TAILLIGHTS              171
# RADIATOR FAN            170
# HEADLIGHTS              169
# CAMSHAFT                166
# SPARK PLUG              165
# COIL SPRING             165
# MUFFLER                 160
# DISTRIBUTOR             158
# PISTON                  123
# LEAF SPRING             120
# Name: count, dtype: int64

# %% [markdown]
# #### TODO: Research about data augmentation and what to do in case of an unbalanced dataset
# ##### At the end of the notebook, you can apply these techniques and train another CNN and compare results

# %% [markdown]
# ### Your task:
#
# #### Quick CNN Workflow for Image Classification
#
# 1. **Load & preprocess data**
#    - Resize images and normalize pixel values (e.g., scale pixels to [0,1])
#    - Prepare labels for classification
#
# 2. **Create training and validation data generators**
#    - Use `ImageDataGenerator` or custom loaders to batch and augment data  (If you want to, or skip this part for now)
#
# 3. **Build the CNN model**
#    - Stack convolutional layers (Conv2D + activation function) and pooling layers
#    - Flatten and add dense layers for final classification
#    - Make sure to use the right activation function for the last Dense layer.
#
# 4. **Compile the model**
#    - Use suitable loss function nd an optimizer like Adam
#
# 5. **Train the model**
#    - Fit the model on training data and validate on validation data over multiple epochs
#    - Find the right number of batches/epochs for your data
#
# 6. **Evaluate and visualize results**
#    - Plot Accuracy & Loss Curves for training/validation
#    - Learn about overfitting/underfitting and how to prevent these situations
#    - Generate confusion matrix and classification report, based on metrics like accuracy
#
# 7. **Explore**
#    - Use a pretrained available model
#    - Change the architecture
#    - Integrate the model into a small GUI and make it more interactive
#    - Test with images from the internet, and see how well it performs

# %% [markdown]
# # Configurations

# %%
from pathlib import Path
import random

import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# reproducibility
SEED = 42
random.seed(SEED)
tf.random.set_seed(SEED)

# dataset paths
DATASET_DIR = Path("./dataset")
CSV_PATH = DATASET_DIR / "car parts.csv"

TRAIN_DIR = DATASET_DIR / "train"
VALID_DIR = DATASET_DIR / "valid"
TEST_DIR = DATASET_DIR / "test"

# image pipeline configuration
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# %%
split_directories = {
    "train": TRAIN_DIR,
    "valid": VALID_DIR,
    "test": TEST_DIR
}

for split_name, split_path in split_directories.items():
    if not split_path.exists():
        raise FileNotFoundError(
            f"The '{split_name}' directory was not found: {split_path}"
        )

    print(f"{split_name}: {split_path}")
# Out:
# train: dataset/train
# valid: dataset/valid
# test: dataset/test

# %%
print(f"Dataset shape: {df.shape}")
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (9239, 4)
#
# Columns:
# ['class index', 'filepaths', 'labels', 'data set']

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# class index    0
# filepaths      0
# labels         0
# data set       0
# dtype: int64

# %%
number_of_classes = df["labels"].nunique()

print(f"Number of classes: {number_of_classes}")
# Out:
# Number of classes: 50

# %%
plt.figure(figsize=(12, 16))

label_counts.plot(kind="barh")

plt.title("Distribution of Car Part Classes")
plt.xlabel("Number of Images")
plt.ylabel("Car Part Class")
plt.grid(axis="x", alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Class Distribution Observation
#
# The dataset contains 50 car part classes. The number of images is not
# identical for all classes, which indicates a degree of class imbalance.
# However, the image loading pipeline will initially use all available
# images without resampling.

# %% [markdown]
# # Pipeline for train, test, validation

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)
# Out:
# Found 8739 files belonging to 50 classes.

# %%
class_names = train_dataset.class_names

print(f"Number of classes: {len(class_names)}")
print("\nClass names:")
print(class_names)

assert len(class_names) == 50, (
    f"Expected 50 classes, but found {len(class_names)}."
)
# Out:
# Number of classes: 50
#
# Class names:
# ['AIR COMPRESSOR', 'ALTERNATOR', 'BATTERY', 'BRAKE CALIPER', 'BRAKE PAD', 'BRAKE ROTOR', 'CAMSHAFT', 'CARBERATOR', 'CLUTCH PLATE', 'COIL SPRING', 'CRANKSHAFT', 'CYLINDER HEAD', 'DISTRIBUTOR', 'ENGINE BLOCK', 'ENGINE VALVE', 'FUEL INJECTOR', 'FUSE BOX', 'GAS CAP', 'HEADLIGHTS', 'IDLER ARM', 'IGNITION COIL', 'INSTRUMENT CLUSTER', 'LEAF SPRING', 'LOWER CONTROL ARM', 'MUFFLER', 'OIL FILTER', 'OIL PAN', 'OIL PRESSURE SENSOR', 'OVERFLOW TANK', 'OXYGEN SENSOR', 'PISTON', 'PRESSURE PLATE', 'RADIATOR', 'RADIATOR FAN', 'RADIATOR HOSE', 'RADIO', 'RIM', 'SHIFT KNOB', 'SIDE MIRROR', 'SPARK PLUG', 'SPOILER', 'STARTER', 'TAILLIGHTS', 'THERMOSTAT', 'TORQUE CONVERTER', 'TRANSMISSION', 'VACUUM BRAKE BOOSTER', 'VALVE LIFTER', 'WATER PUMP', 'WINDOW REGULATOR']

# %%
valid_dataset = tf.keras.utils.image_dataset_from_directory(
    VALID_DIR,
    labels="inferred",
    label_mode="int",
    class_names=class_names,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 250 files belonging to 50 classes.

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="int",
    class_names=class_names,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 250 files belonging to 50 classes.

# %%
def normalize_images(images, labels):
    images = tf.cast(images, tf.float32) / 255.0
    return images, labels

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = (
    train_dataset
    .map(
        normalize_images,
        num_parallel_calls=AUTOTUNE
    )
    .prefetch(AUTOTUNE)
)

valid_dataset = (
    valid_dataset
    .map(
        normalize_images,
        num_parallel_calls=AUTOTUNE
    )
    .prefetch(AUTOTUNE)
)

test_dataset = (
    test_dataset
    .map(
        normalize_images,
        num_parallel_calls=AUTOTUNE
    )
    .prefetch(AUTOTUNE)
)

# %%
datasets = {
    "Train": train_dataset,
    "Validation": valid_dataset,
    "Test": test_dataset
}

for split_name, dataset in datasets.items():
    image_batch, label_batch = next(iter(dataset))

    minimum_pixel_value = tf.reduce_min(image_batch).numpy()
    maximum_pixel_value = tf.reduce_max(image_batch).numpy()

    print(f"\n{split_name} dataset")
    print(f"Image batch shape: {image_batch.shape}")
    print(f"Label batch shape: {label_batch.shape}")
    print(f"Minimum pixel value: {minimum_pixel_value:.4f}")
    print(f"Maximum pixel value: {maximum_pixel_value:.4f}")

    assert minimum_pixel_value >= 0.0
    assert maximum_pixel_value <= 1.0
# Out:
# Train dataset
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Minimum pixel value: 0.0000
# Maximum pixel value: 1.0000
#
# Validation dataset
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Minimum pixel value: 0.0000
# Maximum pixel value: 1.0000
#
# Test dataset
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Minimum pixel value: 0.0000
# Maximum pixel value: 1.0000

# %%
image_batch, label_batch = next(iter(train_dataset))

plt.figure(figsize=(12, 12))

for index in range(9):
    axis = plt.subplot(3, 3, index + 1)

    plt.imshow(image_batch[index].numpy())
    plt.title(
        class_names[int(label_batch[index].numpy())]
    )
    plt.axis("off")

plt.suptitle(
    "Normalized Training Batch",
    fontsize=16
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
#
# The image dataset was successfully explored and prepared for deep learning.
# The metadata confirmed the presence of 50 car part classes, while the class
# distribution plot and sample image grid provided an overview of the dataset
# structure and image variety.
#
# Separate data pipelines were created for the training, validation, and test
# sets. The images were resized to 224x224 pixels, converted to RGB batches, and
# normalized to the [0, 1] range. The batch inspection confirmed that the pipeline
# returns images with the expected shape and one integer class label for each
# image.
#
# The dataset is now ready to be used for building and training a CNN
# classification model.

# %% [markdown]
# # CNN Model Architecture
#
# This section defines a Convolutional Neural Network for classifying car part
# images into 50 classes.
#
# The model contains four convolutional blocks. Each block uses a convolutional
# layer with ReLU activation followed by max pooling. The convolutional layers
# extract progressively more complex visual features, while the pooling layers
# reduce the spatial dimensions of the feature maps.
#
# The extracted features are flattened and passed to a fully connected hidden
# layer. The final Softmax layer produces one probability for each car part class.

# %%
INPUT_SHAPE = (*IMAGE_SIZE, 3)
NUM_CLASSES = len(class_names)

assert IMAGE_SIZE == (224, 224), (
    f"Expected image size (224, 224), but found {IMAGE_SIZE}."
)

assert NUM_CLASSES == 50, (
    f"Expected 50 classes, but found {NUM_CLASSES}."
)

print(f"Model input shape: {INPUT_SHAPE}")
print(f"Number of output classes: {NUM_CLASSES}")
# Out:
# Model input shape: (224, 224, 3)
# Number of output classes: 50

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(
            shape=INPUT_SHAPE,
            name="input_image"
        ),

        # convolutional block 1
        tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="conv_block_1"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="pool_block_1"
        ),

        # convolutional block 2
        tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="conv_block_2"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="pool_block_2"
        ),

        # convolutional block 3
        tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="conv_block_3"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="pool_block_3"
        ),

        # convolutional block 4
        tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="conv_block_4"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="pool_block_4"
        ),

        # classification layers
        tf.keras.layers.Flatten(
            name="flatten_features"
        ),
        tf.keras.layers.Dense(
            units=128,
            activation="relu",
            name="dense_hidden"
        ),
        tf.keras.layers.Dense(
            units=NUM_CLASSES,
            activation="softmax",
            name="class_probabilities"
        )
    ],
    name="car_parts_cnn"
)

# %%
model.summary()
# Out:
# Model: "car_parts_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_block_1 (Conv2D)           │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_block_1 (MaxPooling2D)     │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_block_2 (Conv2D)           │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_block_2 (MaxPooling2D)     │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_block_3 (Conv2D)           │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_block_3 (MaxPooling2D)     │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_block_4 (Conv2D)           │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_block_4 (MaxPooling2D)     │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_features (Flatten)      │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_hidden (Dense)            │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ class_probabilities (Dense)     │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,458,674 (13.19 MB)
#  Trainable params: 3,458,674 (13.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
convolutional_layers = [
    layer
    for layer in model.layers
    if isinstance(layer, tf.keras.layers.Conv2D)
]

pooling_layers = [
    layer
    for layer in model.layers
    if isinstance(layer, tf.keras.layers.MaxPooling2D)
]

output_layer = model.layers[-1]

print(f"Convolutional layers: {len(convolutional_layers)}")
print(f"Pooling layers: {len(pooling_layers)}")
print(f"Model input shape: {model.input_shape}")
print(f"Model output shape: {model.output_shape}")
print(f"Output neurons: {output_layer.units}")
print(f"Output activation: {output_layer.activation.__name__}")

assert len(convolutional_layers) >= 3
assert len(pooling_layers) >= 3
assert model.input_shape == (None, 224, 224, 3)
assert model.output_shape == (None, 50)
assert output_layer.units == 50
assert output_layer.activation.__name__ == "softmax"

print("\nAll architecture requirements were successfully verified.")
# Out:
# Convolutional layers: 4
# Pooling layers: 4
# Model input shape: (None, 224, 224, 3)
# Model output shape: (None, 50)
# Output neurons: 50
# Output activation: softmax
#
# All architecture requirements were successfully verified.

# %% [markdown]
# ### Architecture Analysis
#
# The model receives RGB images with a shape of 224×224×3 and processes them
# through four convolutional blocks. Each max-pooling layer reduces the spatial
# dimensions by half, while the number of filters increases from 32 to 128 to
# capture progressively more complex visual features.
#
# After the final pooling operation, the feature maps have a shape of
# 14×14×128. The `Flatten` layer converts them into a vector of 25,088 values,
# which is passed to a hidden layer with 128 neurons.
#
# Most of the model parameters are located in the hidden Dense layer because
# each flattened feature is connected to every Dense neuron. The fourth
# convolutional block reduces the feature-map dimensions before flattening,
# significantly limiting the number of Dense parameters.
#
# The final layer contains 50 neurons with Softmax activation, producing one
# class probability for each car part category.

# %%
convolutional_layers = [
    layer
    for layer in model.layers
    if isinstance(layer, tf.keras.layers.Conv2D)
]

pooling_layers = [
    layer
    for layer in model.layers
    if isinstance(layer, tf.keras.layers.MaxPooling2D)
]

dense_layers = [
    layer
    for layer in model.layers
    if isinstance(layer, tf.keras.layers.Dense)
]

output_layer = model.layers[-1]

print(f"Convolutional layers: {len(convolutional_layers)}")
print(f"Pooling layers: {len(pooling_layers)}")
print(f"Dense layers: {len(dense_layers)}")
print(f"Model input shape: {model.input_shape}")
print(f"Model output shape: {model.output_shape}")
print(f"Output neurons: {output_layer.units}")
print(f"Output activation: {output_layer.activation.__name__}")

assert len(convolutional_layers) >= 3, (
    "The model must contain at least three convolutional layers."
)

assert len(pooling_layers) >= 3, (
    "The model must contain at least three pooling layers."
)

assert len(dense_layers) >= 2, (
    "The model must contain at least one hidden Dense layer "
    "and one output Dense layer."
)

assert model.input_shape == (None, 224, 224, 3), (
    f"Unexpected input shape: {model.input_shape}"
)

assert model.output_shape == (None, 50), (
    f"Unexpected output shape: {model.output_shape}"
)

assert output_layer.units == 50, (
    f"Expected 50 output neurons, but found {output_layer.units}."
)

assert output_layer.activation.__name__ == "softmax", (
    "The output layer must use Softmax activation."
)

print("\nAll CNN architecture requirements were successfully verified.")
# Out:
# Convolutional layers: 4
# Pooling layers: 4
# Dense layers: 2
# Model input shape: (None, 224, 224, 3)
# Model output shape: (None, 50)
# Output neurons: 50
# Output activation: softmax
#
# All CNN architecture requirements were successfully verified.

# %% [markdown]
# ## CNN Architecture Conclusion
#
# A custom CNN architecture was defined for the classification of 50 car part
# categories. The model accepts RGB images with a resolution of 224×224 pixels
# and contains four convolutional blocks.
#
# Each block combines a `Conv2D` layer with ReLU activation and a
# `MaxPooling2D` layer. The number of filters increases from 32 to 128 as the
# spatial dimensions decrease, allowing the model to represent progressively
# more complex visual features.
#
# After the final convolutional block, the feature maps are flattened and passed
# to a hidden Dense layer with 128 neurons. The output layer contains 50 neurons
# with Softmax activation, producing one class probability for each car part
# category.
#
# The model contains 3,458,674 trainable parameters. Most of these parameters
# belong to the hidden Dense layer because every flattened feature is connected
# to every neuron in that layer.

# %% [markdown]
# # Model Training
#
# The CNN is compiled using the Adam optimizer and sparse categorical
# cross-entropy loss.
#
# Sparse categorical cross-entropy is used because the dataset labels are
# represented as integer class indices from 0 to 49. Accuracy is monitored
# during training and validation to measure the percentage of correctly
# classified images.

# %%
LEARNING_RATE = 0.001
EPOCHS = 15

optimizer = tf.keras.optimizers.Adam(
    learning_rate=LEARNING_RATE
)

model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully.")
print(f"Optimizer: {model.optimizer.__class__.__name__}")
print(f"Learning rate: {float(model.optimizer.learning_rate.numpy())}")
print(f"Loss function: {model.loss}")
print(f"Metrics: accuracy")
print(f"Planned epochs: {EPOCHS}")
# Out:
# Model compiled successfully.
# Optimizer: Adam
# Learning rate: 0.0010000000474974513
# Loss function: sparse_categorical_crossentropy
# Metrics: accuracy
# Planned epochs: 15

# %% [markdown]
# ## CNN Training
#
# The CNN will be trained on the training dataset for 15 epochs using batches
# of 32 images. After each epoch, the model will be evaluated on the validation
# dataset.
#
# The validation dataset is used only to monitor generalization performance.
# Its images do not contribute to the weight updates performed by the Adam
# optimizer.

# %%
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# Epoch 1/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - accuracy: 0.2008 - loss: 3.1518 - val_accuracy: 0.3720 - val_loss: 2.4055
# Epoch 2/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.5047 - loss: 1.8672 - val_accuracy: 0.4040 - val_loss: 2.3449
# Epoch 3/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.6839 - loss: 1.1361 - val_accuracy: 0.4640 - val_loss: 2.2797
# Epoch 4/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.8215 - loss: 0.6011 - val_accuracy: 0.5000 - val_loss: 2.6394
# Epoch 5/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.9172 - loss: 0.2727 - val_accuracy: 0.4800 - val_loss: 3.1756
# Epoch 6/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.9476 - loss: 0.1783 - val_accuracy: 0.4840 - val_loss: 3.5264
# Epoch 7/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.9574 - loss: 0.1437 - val_accuracy: 0.5120 - val_loss: 3.8071
# Epoch 8/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.9700 - loss: 0.0976 - val_accuracy: 0.4960 - val_loss: 4.2228
# Epoch 9/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9748 - loss: 0.0874 - val_accuracy: 0.5240 - val_loss: 4.4874
# Epoch 10/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9796 - loss: 0.0623 - val_accuracy: 0.5000 - val_loss: 4.2100
# Epoch 11/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9743 - loss: 0.0853 - val_accuracy: 0.5000 - val_loss: 4.5037
# Epoch 12/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9835 - loss: 0.0529 - val_accuracy: 0.5160 - val_loss: 4.8743
# Epoch 13/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9744 - loss: 0.0914 - val_accuracy: 0.4680 - val_loss: 4.8148
# Epoch 14/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9887 - loss: 0.0361 - val_accuracy: 0.5120 - val_loss: 5.4376
# Epoch 15/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9797 - loss: 0.0681 - val_accuracy: 0.4800 - val_loss: 4.7066

# %%
history_df = pd.DataFrame(history.history)

history_df.index = range(1, len(history_df) + 1)
history_df.index.name = "Epoch"

required_metrics = {
    "loss",
    "accuracy",
    "val_loss",
    "val_accuracy"
}

missing_metrics = required_metrics.difference(
    history_df.columns
)

assert not missing_metrics, (
    f"Missing training metrics: {missing_metrics}"
)

assert len(history_df) == EPOCHS, (
    f"Expected {EPOCHS} completed epochs, "
    f"but found {len(history_df)}."
)

print(f"Completed epochs: {len(history_df)}")
display(history_df.round(4))
# Out:
# Completed epochs: 15
#        accuracy    loss  val_accuracy  val_loss
# Epoch
# 1        0.2008  3.1518         0.372    2.4055
# 2        0.5047  1.8672         0.404    2.3449
# 3        0.6839  1.1361         0.464    2.2797
# 4        0.8215  0.6011         0.500    2.6394
# 5        0.9172  0.2727         0.480    3.1756
# 6        0.9476  0.1783         0.484    3.5264
# 7        0.9574  0.1437         0.512    3.8071
# 8        0.9700  0.0976         0.496    4.2228
# 9        0.9748  0.0874         0.524    4.4874
# 10       0.9796  0.0623         0.500    4.2100
# 11       0.9743  0.0853         0.500    4.5037
# 12       0.9835  0.0529         0.516    4.8743
# 13       0.9744  0.0914         0.468    4.8148
# 14       0.9887  0.0361         0.512    5.4376
# 15       0.9797  0.0681         0.480    4.7066

# %% [markdown]
# ## Training Curves
#
# The training history is used to visualize how the model's loss and accuracy
# change across epochs.
#
# Training and validation metrics are plotted together to evaluate whether the
# model learns useful patterns and generalizes to unseen validation images.

# %%
training_loss = history.history["loss"]
validation_loss = history.history["val_loss"]

epochs_range = range(1, len(training_loss) + 1)

plt.figure(figsize=(10, 6))

plt.plot(
    epochs_range,
    training_loss,
    marker="o",
    label="Training Loss"
)

plt.plot(
    epochs_range,
    validation_loss,
    marker="o",
    label="Validation Loss"
)

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xticks(epochs_range)
plt.legend()
plt.grid(True)
plt.show()

# %%
training_accuracy = history.history["accuracy"]
validation_accuracy = history.history["val_accuracy"]

plt.figure(figsize=(10, 6))

plt.plot(
    epochs_range,
    training_accuracy,
    marker="o",
    label="Training Accuracy"
)

plt.plot(
    epochs_range,
    validation_accuracy,
    marker="o",
    label="Validation Accuracy"
)

plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xticks(epochs_range)
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

best_loss_epoch = np.argmin(validation_loss) + 1
best_accuracy_epoch = np.argmax(validation_accuracy) + 1

best_validation_loss = validation_loss[best_loss_epoch - 1]
best_validation_accuracy = validation_accuracy[
    best_accuracy_epoch - 1
]

print(
    f"Best validation loss: "
    f"{best_validation_loss:.4f} "
    f"at epoch {best_loss_epoch}"
)

print(
    f"Best validation accuracy: "
    f"{best_validation_accuracy:.4f} "
    f"at epoch {best_accuracy_epoch}"
)
# Out:
# Best validation loss: 2.2797 at epoch 3
# Best validation accuracy: 0.5240 at epoch 9

# %% [markdown]
# ## Training Analysis and Conclusion
#
# The baseline CNN shows clear signs of overfitting. The lowest validation loss,
# **2.2797**, was reached at epoch 3. After this point, the training loss continued
# to decrease, while the validation loss generally increased.
#
# At epoch 15, the model achieved a training accuracy of **97.97%** and a training
# loss of **0.0681**. In comparison, the validation accuracy was **48.00%**, while
# the validation loss increased to **4.7066**.
#
# The highest validation accuracy, **52.40%**, was reached at epoch 9. However,
# the validation loss at that epoch was already **4.4874**, considerably higher
# than the minimum validation loss reached at epoch 3.
#
# This difference indicates that the model became increasingly confident in its
# predictions without achieving a proportional improvement on unseen validation
# images. Based on validation loss, epoch 3 represents the strongest
# generalization point.
#
# These results indicate severe overfitting. Data augmentation, Dropout, early
# stopping, Batch Normalization, L2 regularization, or a less parameter-heavy
# architecture could help improve generalization.

# %% [markdown]
# # Test Set Evaluation
#
# The trained CNN is evaluated exclusively on the test set. This section reports
# the overall test accuracy, per-class precision, recall and F1-score, and analyzes
# the most frequent classification errors using a confusion matrix.

# %%
import numpy as np
import seaborn as sns

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
test_probabilities = model.predict(
    test_dataset,
    verbose=1
)

y_pred = np.argmax(
    test_probabilities,
    axis=1
)

y_true = np.concatenate(
    [
        label_batch.numpy()
        for _, label_batch in test_dataset
    ],
    axis=0
).astype(int)

print(f"Prediction probabilities shape: {test_probabilities.shape}")
print(f"Predicted labels shape: {y_pred.shape}")
print(f"True labels shape: {y_true.shape}")

assert test_probabilities.shape == (
    len(y_true),
    NUM_CLASSES
), (
    "The prediction matrix does not have the expected shape."
)

assert len(y_pred) == len(y_true), (
    "The number of predictions does not match "
    "the number of true labels."
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# Prediction probabilities shape: (250, 50)
# Predicted labels shape: (250,)
# True labels shape: (250,)

# %%
test_accuracy = accuracy_score(
    y_true,
    y_pred
)

print(f"Overall test accuracy: {test_accuracy:.4f}")
print(f"Overall test accuracy: {test_accuracy * 100:.2f}%")

print("\nClassification Report:\n")

report = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=class_names,
    digits=4,
    zero_division=0
)

print(report)
# Out:
# Overall test accuracy: 0.4920
# Overall test accuracy: 49.20%
#
# Classification Report:
#
#                       precision    recall  f1-score   support
#
#       AIR COMPRESSOR     0.6000    0.6000    0.6000         5
#           ALTERNATOR     1.0000    0.6000    0.7500         5
#              BATTERY     1.0000    0.6000    0.7500         5
#        BRAKE CALIPER     0.5000    0.6000    0.5455         5
#            BRAKE PAD     0.4000    0.4000    0.4000         5
#          BRAKE ROTOR     0.2500    0.2000    0.2222         5
#             CAMSHAFT     1.0000    0.4000    0.5714         5
#           CARBERATOR     0.2632    1.0000    0.4167         5
#         CLUTCH PLATE     1.0000    0.8000    0.8889         5
#          COIL SPRING     0.7500    0.6000    0.6667         5
#           CRANKSHAFT     0.7500    0.6000    0.6667         5
#        CYLINDER HEAD     0.5000    0.2000    0.2857         5
#          DISTRIBUTOR     0.4000    0.4000    0.4000         5
#         ENGINE BLOCK     0.5000    0.6000    0.5455         5
#         ENGINE VALVE     1.0000    0.4000    0.5714         5
#        FUEL INJECTOR     1.0000    0.4000    0.5714         5
#             FUSE BOX     0.3333    0.6000    0.4286         5
#              GAS CAP     0.5714    0.8000    0.6667         5
#           HEADLIGHTS     0.4286    0.6000    0.5000         5
#            IDLER ARM     0.0000    0.0000    0.0000         5
#        IGNITION COIL     0.0000    0.0000    0.0000         5
#   INSTRUMENT CLUSTER     1.0000    0.8000    0.8889         5
#          LEAF SPRING     0.0000    0.0000    0.0000         5
#    LOWER CONTROL ARM     0.0000    0.0000    0.0000         5
#              MUFFLER     1.0000    0.2000    0.3333         5
#           OIL FILTER     0.4444    0.8000    0.5714         5
#              OIL PAN     0.0000    0.0000    0.0000         5
#  OIL PRESSURE SENSOR     0.3333    0.8000    0.4706         5
#        OVERFLOW TANK     1.0000    0.2000    0.3333         5
#        OXYGEN SENSOR     0.4000    0.8000    0.5333         5
#               PISTON     0.6000    0.6000    0.6000         5
#       PRESSURE PLATE     0.6667    0.8000    0.7273         5
#             RADIATOR     0.5714    0.8000    0.6667         5
#         RADIATOR FAN     0.6000    0.6000    0.6000         5
#        RADIATOR HOSE     0.1667    0.2000    0.1818         5
#                RADIO     0.6667    0.8000    0.7273         5
#                  RIM     1.0000    0.6000    0.7500         5
#           SHIFT KNOB     0.5000    0.4000    0.4444         5
#          SIDE MIRROR     0.6667    0.4000    0.5000         5
#           SPARK PLUG     0.6000    0.6000    0.6000         5
#              SPOILER     0.7500    0.6000    0.6667         5
#              STARTER     0.5000    0.6000    0.5455         5
#           TAILLIGHTS     0.7500    0.6000    0.6667         5
#           THERMOSTAT     1.0000    0.2000    0.3333         5
#     TORQUE CONVERTER     1.0000    0.4000    0.5714         5
#         TRANSMISSION     0.6667    0.4000    0.5000         5
# VACUUM BRAKE BOOSTER     0.2000    0.2000    0.2000         5
#         VALVE LIFTER     0.4545    1.0000    0.6250         5
#           WATER PUMP     0.2000    0.2000    0.2000         5
#     WINDOW REGULATOR     0.3750    0.6000    0.4615         5
#
#             accuracy                         0.4920       250
#            macro avg     0.5672    0.4920    0.4829       250
#         weighted avg     0.5672    0.4920    0.4829       250

# %%
test_confusion_matrix = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES)
)

print(
    "Confusion matrix shape:",
    test_confusion_matrix.shape
)

assert test_confusion_matrix.shape == (
    NUM_CLASSES,
    NUM_CLASSES
), (
    "The confusion matrix does not have "
    "the expected shape."
)

plt.figure(figsize=(24, 20))

sns.heatmap(
    test_confusion_matrix,
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names,
    annot=False,
    cbar=True,
    linewidths=0.1
)

plt.title(
    "Test Set Confusion Matrix",
    fontsize=18
)

plt.xlabel(
    "Predicted Class",
    fontsize=14
)

plt.ylabel(
    "True Class",
    fontsize=14
)

plt.xticks(
    rotation=90,
    fontsize=8
)

plt.yticks(
    rotation=0,
    fontsize=8
)

plt.tight_layout()
plt.show()
# Out:
# Confusion matrix shape: (50, 50)

# %%
confused_pairs = []

for first_class_index in range(NUM_CLASSES):
    for second_class_index in range(
        first_class_index + 1,
        NUM_CLASSES
    ):
        first_as_second = test_confusion_matrix[
            first_class_index,
            second_class_index
        ]

        second_as_first = test_confusion_matrix[
            second_class_index,
            first_class_index
        ]

        total_confusions = (
            first_as_second + second_as_first
        )

        if total_confusions > 0:
            confused_pairs.append(
                {
                    "Class A": class_names[
                        first_class_index
                    ],
                    "Class B": class_names[
                        second_class_index
                    ],
                    "A predicted as B": int(
                        first_as_second
                    ),
                    "B predicted as A": int(
                        second_as_first
                    ),
                    "Total confusions": int(
                        total_confusions
                    )
                }
            )

confused_pairs_df = pd.DataFrame(
    confused_pairs
).sort_values(
    by="Total confusions",
    ascending=False
).reset_index(drop=True)

top_3_confused_pairs = confused_pairs_df.head(3)

print("Top 3 most confused class pairs:")
display(top_3_confused_pairs)

assert len(top_3_confused_pairs) == 3, (
    "Expected three confused class pairs."
)
# Out:
# Top 3 most confused class pairs:
#          Class A              Class B  A predicted as B  B predicted as A  \
# 0  IGNITION COIL  OIL PRESSURE SENSOR                 3                 0
# 1      BRAKE PAD        RADIATOR HOSE                 0                 2
# 2    DISTRIBUTOR     WINDOW REGULATOR                 1                 1
#
#    Total confusions
# 0                 3
# 1                 2
# 2                 2

# %%
test_images = np.concatenate(
    [
        image_batch.numpy()
        for image_batch, _ in test_dataset
    ],
    axis=0
)

print(f"Collected test images shape: {test_images.shape}")

assert len(test_images) == len(y_true), (
    "The number of collected test images does not match "
    "the number of true labels."
)
# Out:
# Collected test images shape: (250, 224, 224, 3)

# %%
MAX_EXAMPLES_PER_PAIR = 3

figure, axes = plt.subplots(
    nrows=3,
    ncols=MAX_EXAMPLES_PER_PAIR,
    figsize=(15, 12)
)

for row_index, (_, pair) in enumerate(
    top_3_confused_pairs.iterrows()
):
    class_a_name = pair["Class A"]
    class_b_name = pair["Class B"]

    class_a_index = class_names.index(class_a_name)
    class_b_index = class_names.index(class_b_name)

    confused_image_indices = np.where(
        (
            (y_true == class_a_index)
            & (y_pred == class_b_index)
        )
        |
        (
            (y_true == class_b_index)
            & (y_pred == class_a_index)
        )
    )[0]

    for column_index in range(
        MAX_EXAMPLES_PER_PAIR
    ):
        axis = axes[row_index, column_index]

        if column_index < len(confused_image_indices):
            image_index = confused_image_indices[
                column_index
            ]

            true_class_name = class_names[
                y_true[image_index]
            ]

            predicted_class_name = class_names[
                y_pred[image_index]
            ]

            axis.imshow(test_images[image_index])

            axis.set_title(
                f"True: {true_class_name}\n"
                f"Predicted: {predicted_class_name}",
                fontsize=10
            )
        else:
            axis.set_visible(False)

        axis.axis("off")

    axes[row_index, 0].set_ylabel(
        f"{class_a_name}\nvs\n{class_b_name}",
        fontsize=11
    )

plt.suptitle(
    "Examples from the Top-3 Most Confused Class Pairs",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test Evaluation and Confusion Analysis
#
# The baseline CNN achieved an overall test accuracy of **49.20%**, correctly
# classifying **123 out of 250 test images**. The macro-average and weighted-average
# F1-scores are both approximately **0.4829**. These values are equal because the
# test dataset is balanced, with five images for each of the 50 classes.
#
# The best-performing classes were `CLUTCH PLATE` and `INSTRUMENT CLUSTER`,
# each reaching an F1-score of approximately **0.8889**, followed by `ALTERNATOR`
# with an F1-score of **0.7500**.
#
# Performance varied considerably between classes. `IDLER ARM`, `IGNITION COIL`,
# `LEAF SPRING`, `LOWER CONTROL ARM`, and `OIL PAN` obtained a recall of
# **0.0000**, meaning that none of their test images were correctly classified.
#
# ### Top-3 Most Confused Class Pairs
#
# #### 1. IGNITION COIL vs OIL PRESSURE SENSOR
#
# This pair produced **3 total confusions**, with three `IGNITION COIL` images
# classified as `OIL PRESSURE SENSOR`.
#
# The displayed components share compact cylindrical bodies, metallic or dark
# surfaces, electrical connectors, and isolated white backgrounds. The model may
# therefore focus on their similar overall shape and connector regions rather than
# on the smaller structural details that distinguish the components.
#
# #### 2. BRAKE PAD vs RADIATOR HOSE
#
# This pair produced **2 total confusions**, with two `RADIATOR HOSE` images
# classified as `BRAKE PAD`.
#
# The confused images contain dark components photographed individually against
# simple backgrounds. Their strong edges, curved contours, and limited contextual
# information may cause the model to rely on general shape and color patterns
# instead of component-specific features.
#
# #### 3. DISTRIBUTOR vs WINDOW REGULATOR
#
# This pair produced **2 total confusions**, one in each direction.
#
# Both components contain elongated metallic structures, dark mechanical parts,
# wires or cables, and complex outlines on white backgrounds. These shared visual
# characteristics may make it difficult for the model to distinguish between them,
# especially when the surrounding vehicle context is absent.
#
# ### Conclusion
#
# The classification report and confusion matrix show that accuracy alone does
# not fully describe the model's performance. Some classes are recognized
# reliably, while others are never correctly identified.
#
# The baseline model achieved very high performance on the training set but only
# **49.20% accuracy** on unseen test images. This confirms that the model
# overfits the training data and does not generalize consistently across all car
# part classes.
#
# The following regularization experiment evaluates whether data augmentation
# and Dropout can reduce this overfitting.

# %%
report_dictionary = classification_report(
    y_true,
    y_pred,
    labels=np.arange(NUM_CLASSES),
    target_names=class_names,
    output_dict=True,
    zero_division=0
)

class_metrics = pd.DataFrame(
    report_dictionary
).transpose()

class_metrics = class_metrics.loc[
    class_names,
    [
        "precision",
        "recall",
        "f1-score",
        "support"
    ]
]

top_3_best_classes = (
    class_metrics
    .sort_values(
        by=[
            "f1-score",
            "recall",
            "precision"
        ],
        ascending=False
    )
    .head(3)
)

print("Top-3 best performing classes:")
display(top_3_best_classes)
# Out:
# Top-3 best performing classes:
#                     precision  recall  f1-score  support
# CLUTCH PLATE              1.0     0.8  0.888889      5.0
# INSTRUMENT CLUSTER        1.0     0.8  0.888889      5.0
# ALTERNATOR                1.0     0.6  0.750000      5.0

# %% [markdown]
# # Regularization Experiment
#
# The baseline CNN is compared with a regularized version that uses data
# augmentation and dropout. Both models are trained for the same number of epochs
# and evaluated on the same validation and test datasets.

# %%
baseline_model = model

baseline_history = {
    metric_name: metric_values.copy()
    for metric_name, metric_values
    in history.history.items()
}

baseline_test_loss, baseline_test_accuracy = (
    baseline_model.evaluate(
        test_dataset,
        verbose=0
    )
)

print(
    f"Baseline test loss: "
    f"{baseline_test_loss:.4f}"
)

print(
    f"Baseline test accuracy: "
    f"{baseline_test_accuracy:.4f} "
    f"({baseline_test_accuracy * 100:.2f}%)"
)
# Out:
# Baseline test loss: 4.5238
# Baseline test accuracy: 0.4920 (49.20%)

# %%
baseline_probabilities = baseline_model.predict(
    test_dataset,
    verbose=0
)

baseline_predictions = np.argmax(
    baseline_probabilities,
    axis=1
)

verified_baseline_accuracy = accuracy_score(
    y_true,
    baseline_predictions
)

print(
    f"Accuracy from model.evaluate: "
    f"{baseline_test_accuracy:.4f}"
)

print(
    f"Accuracy from predictions: "
    f"{verified_baseline_accuracy:.4f}"
)

assert np.isclose(
    baseline_test_accuracy,
    verified_baseline_accuracy
), (
    "The two baseline accuracy values do not match."
)
# Out:
# Accuracy from model.evaluate: 0.4920
# Accuracy from predictions: 0.4920

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip(
            mode="horizontal",
            seed=SEED
        ),
        tf.keras.layers.RandomRotation(
            factor=0.05,
            seed=SEED
        ),
        tf.keras.layers.RandomZoom(
            height_factor=0.10,
            width_factor=0.10,
            seed=SEED
        )
    ],
    name="data_augmentation"
)

# %%
sample_images, sample_labels = next(
    iter(train_dataset)
)

augmented_images = data_augmentation(
    sample_images[:9],
    training=True
)

plt.figure(figsize=(12, 12))

for index in range(9):
    plt.subplot(3, 3, index + 1)

    plt.imshow(
        augmented_images[index].numpy()
    )

    plt.title(
        class_names[
            int(sample_labels[index].numpy())
        ]
    )

    plt.axis("off")

plt.suptitle(
    "Augmented Training Images",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
regularized_model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(
            shape=INPUT_SHAPE,
            name="input_image"
        ),

        data_augmentation,

        # convolutional block 1
        tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="regularized_conv_1"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="regularized_pool_1"
        ),
        tf.keras.layers.Dropout(
            rate=0.25,
            name="dropout_conv_1"
        ),

        # convolutional block 2
        tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="regularized_conv_2"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="regularized_pool_2"
        ),
        tf.keras.layers.Dropout(
            rate=0.25,
            name="dropout_conv_2"
        ),

        # convolutional block 3
        tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="regularized_conv_3"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="regularized_pool_3"
        ),
        tf.keras.layers.Dropout(
            rate=0.25,
            name="dropout_conv_3"
        ),

        # convolutional block 4
        tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            name="regularized_conv_4"
        ),
        tf.keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            name="regularized_pool_4"
        ),
        tf.keras.layers.Dropout(
            rate=0.25,
            name="dropout_conv_4"
        ),

        # classification layers
        tf.keras.layers.Flatten(
            name="regularized_flatten"
        ),
        tf.keras.layers.Dense(
            units=128,
            activation="relu",
            name="regularized_dense_hidden"
        ),
        tf.keras.layers.Dropout(
            rate=0.50,
            name="dropout_dense"
        ),
        tf.keras.layers.Dense(
            units=NUM_CLASSES,
            activation="softmax",
            name="regularized_class_probabilities"
        )
    ],
    name="regularized_car_parts_cnn"
)

regularized_model.summary()
# Out:
# Model: "regularized_car_parts_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_conv_1 (Conv2D)     │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_pool_1              │ (None, 112, 112, 32)   │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_conv_1 (Dropout)        │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_conv_2 (Conv2D)     │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_pool_2              │ (None, 56, 56, 64)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_conv_2 (Dropout)        │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_conv_3 (Conv2D)     │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_pool_3              │ (None, 28, 28, 128)    │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_conv_3 (Dropout)        │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_conv_4 (Conv2D)     │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_pool_4              │ (None, 14, 14, 128)    │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_conv_4 (Dropout)        │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_flatten (Flatten)   │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_dense_hidden        │ (None, 128)            │     3,211,392 │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_dense (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regularized_class_probabilities │ (None, 50)             │         6,450 │
# │ (Dense)                         │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,458,674 (13.19 MB)
#  Trainable params: 3,458,674 (13.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
regularized_optimizer = tf.keras.optimizers.Adam(
    learning_rate=LEARNING_RATE
)

regularized_model.compile(
    optimizer=regularized_optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Regularized model compiled successfully.")
# Out:
# Regularized model compiled successfully.

# %%
regularized_history_object = regularized_model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# Epoch 1/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 28s 93ms/step - accuracy: 0.0192 - loss: 3.9296 - val_accuracy: 0.0200 - val_loss: 3.9124
# Epoch 2/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - accuracy: 0.0426 - loss: 3.8182 - val_accuracy: 0.0920 - val_loss: 3.6996
# Epoch 3/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 92ms/step - accuracy: 0.1018 - loss: 3.5566 - val_accuracy: 0.2280 - val_loss: 3.2825
# Epoch 4/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - accuracy: 0.1539 - loss: 3.2704 - val_accuracy: 0.2880 - val_loss: 2.9924
# Epoch 5/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.1921 - loss: 3.0773 - val_accuracy: 0.3280 - val_loss: 2.6432
# Epoch 6/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.2262 - loss: 2.9300 - val_accuracy: 0.3680 - val_loss: 2.5758
# Epoch 7/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.2516 - loss: 2.8017 - val_accuracy: 0.3200 - val_loss: 2.6388
# Epoch 8/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.2709 - loss: 2.6832 - val_accuracy: 0.3400 - val_loss: 2.4499
# Epoch 9/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.2966 - loss: 2.5869 - val_accuracy: 0.4120 - val_loss: 2.2958
# Epoch 10/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.3110 - loss: 2.5206 - val_accuracy: 0.3600 - val_loss: 2.5135
# Epoch 11/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.3213 - loss: 2.4523 - val_accuracy: 0.4200 - val_loss: 2.2462
# Epoch 12/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.3393 - loss: 2.3633 - val_accuracy: 0.3920 - val_loss: 2.3295
# Epoch 13/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.3514 - loss: 2.3360 - val_accuracy: 0.3520 - val_loss: 2.3381
# Epoch 14/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.3611 - loss: 2.2821 - val_accuracy: 0.4840 - val_loss: 2.1092
# Epoch 15/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - accuracy: 0.3766 - loss: 2.2243 - val_accuracy: 0.4720 - val_loss: 1.9755

# %%
regularized_history = {
    metric_name: metric_values.copy()
    for metric_name, metric_values
    in regularized_history_object.history.items()
}

# %%
regularized_test_loss, regularized_test_accuracy = (
    regularized_model.evaluate(
        test_dataset,
        verbose=0
    )
)

print(
    f"Baseline test accuracy: "
    f"{baseline_test_accuracy:.4f} "
    f"({baseline_test_accuracy * 100:.2f}%)"
)

print(
    f"Regularized test accuracy: "
    f"{regularized_test_accuracy:.4f} "
    f"({regularized_test_accuracy * 100:.2f}%)"
)

accuracy_difference = (
    regularized_test_accuracy
    - baseline_test_accuracy
)

print(
    f"Accuracy difference: "
    f"{accuracy_difference:+.4f} "
    f"({accuracy_difference * 100:+.2f} percentage points)"
)
# Out:
# Baseline test accuracy: 0.4920 (49.20%)
# Regularized test accuracy: 0.4640 (46.40%)
# Accuracy difference: -0.0280 (-2.80 percentage points)

# %%
epochs_range = range(
    1,
    len(baseline_history["loss"]) + 1
)

plt.figure(figsize=(12, 7))

plt.plot(
    epochs_range,
    baseline_history["loss"],
    label="Baseline Training Loss"
)

plt.plot(
    epochs_range,
    baseline_history["val_loss"],
    label="Baseline Validation Loss"
)

plt.plot(
    epochs_range,
    regularized_history["loss"],
    label="Regularized Training Loss"
)

plt.plot(
    epochs_range,
    regularized_history["val_loss"],
    label="Regularized Validation Loss"
)

plt.title(
    "Baseline vs Regularized Model - Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
epochs_range = range(
    1,
    len(baseline_history["accuracy"]) + 1
)

plt.figure(figsize=(12, 7))

plt.plot(
    epochs_range,
    baseline_history["accuracy"],
    label="Baseline Training Accuracy"
)

plt.plot(
    epochs_range,
    baseline_history["val_accuracy"],
    label="Baseline Validation Accuracy"
)

plt.plot(
    epochs_range,
    regularized_history["accuracy"],
    label="Regularized Training Accuracy"
)

plt.plot(
    epochs_range,
    regularized_history["val_accuracy"],
    label="Regularized Validation Accuracy"
)

plt.title(
    "Baseline vs Regularized Model - Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Baseline vs Regularized Model
#
# The baseline CNN achieved a test accuracy of **49.20%**, while the regularized
# model achieved **46.40%** after the same 15 training epochs. Therefore, the
# regularized model decreased test accuracy by **2.80 percentage points**,
# corresponding to **7 fewer correctly classified test images**.
#
# The baseline model showed severe overfitting. At epoch 15, its training accuracy
# reached **97.97%**, while its validation accuracy was only **48.00%**. The
# training loss decreased to **0.0681**, while the validation loss increased to
# **4.7066**.
#
# The regularized model behaved differently. At epoch 15, it achieved a training
# accuracy of **37.66%**, a validation accuracy of **47.20%**, a training loss of
# **2.2243**, and a validation loss of **1.9755**.
#
# The validation accuracy being higher than the training accuracy is expected.
# During training, data augmentation makes the input images more difficult and
# Dropout temporarily disables part of the model's activations. These operations
# are inactive during validation and testing.
#
# ### Did augmentation help?
#
# The combination of data augmentation and Dropout substantially reduced the
# overfitting observed in the baseline model. The difference between training and
# validation accuracy became much smaller, and the validation loss remained
# considerably lower than that of the baseline model.
#
# However, the regularized model obtained a slightly lower test accuracy after the
# same 15 training epochs. This indicates that regularization improved the model's
# training behavior but also slowed down the learning process.
#
# Therefore, data augmentation and Dropout did not improve test accuracy within
# the fixed 15-epoch comparison. The model may require additional training to
# benefit fully from regularization.

# %% [markdown]
# ## Additional Experiment: Extended Training
#
# The regularized model was still learning at the end of the fixed 15-epoch
# experiment. Therefore, an additional experiment continues training the same
# model for up to 40 total epochs.
#
# Early stopping is used to stop training when the validation loss no longer
# improves. ReduceLROnPlateau decreases the learning rate when progress slows,
# allowing the optimizer to make smaller and more precise weight updates.
#
# This experiment is reported separately because the official baseline comparison
# uses the same fixed number of 15 epochs for both models.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_learning_rate = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2,
    min_lr=0.00001,
    verbose=1
)

improved_history = regularized_model.fit(
    train_dataset,
    validation_data=valid_dataset,
    initial_epoch=15,
    epochs=40,
    callbacks=[
        early_stopping,
        reduce_learning_rate
    ],
    verbose=1
)
# Out:
# Epoch 16/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.3844 - loss: 2.1732 - val_accuracy: 0.3760 - val_loss: 2.2242 - learning_rate: 0.0010
# Epoch 17/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.3973 - loss: 2.1247 - val_accuracy: 0.4760 - val_loss: 1.9932 - learning_rate: 0.0010
# Epoch 18/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 88ms/step - accuracy: 0.4118 - loss: 2.0838 - val_accuracy: 0.4400 - val_loss: 2.0185 - learning_rate: 0.0010
# Epoch 19/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4122 - loss: 2.0542 - val_accuracy: 0.4560 - val_loss: 1.9831 - learning_rate: 0.0010
# Epoch 20/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.4126 - loss: 2.0397 - val_accuracy: 0.5040 - val_loss: 1.9270 - learning_rate: 0.0010
# Epoch 21/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4323 - loss: 1.9816 - val_accuracy: 0.3840 - val_loss: 2.4439 - learning_rate: 0.0010
# Epoch 22/40
# 273/274 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4269 - loss: 1.9846
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 88ms/step - accuracy: 0.4267 - loss: 1.9682 - val_accuracy: 0.4480 - val_loss: 2.0549 - learning_rate: 0.0010
# Epoch 23/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - accuracy: 0.4608 - loss: 1.8598 - val_accuracy: 0.5120 - val_loss: 1.8238 - learning_rate: 5.0000e-04
# Epoch 24/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4679 - loss: 1.8222 - val_accuracy: 0.4400 - val_loss: 2.2434 - learning_rate: 5.0000e-04
# Epoch 25/40
# 273/274 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4704 - loss: 1.8039
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.4700 - loss: 1.7994 - val_accuracy: 0.4680 - val_loss: 2.0278 - learning_rate: 5.0000e-04
# Epoch 26/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4886 - loss: 1.7311 - val_accuracy: 0.4400 - val_loss: 2.1406 - learning_rate: 2.5000e-04
# Epoch 27/40
# 273/274 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4962 - loss: 1.7158
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4924 - loss: 1.7150 - val_accuracy: 0.4920 - val_loss: 1.9217 - learning_rate: 2.5000e-04
# Epoch 28/40
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.4954 - loss: 1.6849 - val_accuracy: 0.4640 - val_loss: 2.0309 - learning_rate: 1.2500e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
improved_test_loss, improved_test_accuracy = (
    regularized_model.evaluate(
        test_dataset,
        verbose=0
    )
)

print(
    f"Baseline test accuracy: "
    f"{baseline_test_accuracy * 100:.2f}%"
)

print(
    f"Regularized test accuracy after additional training: "
    f"{improved_test_accuracy * 100:.2f}%"
)
# Out:
# Baseline test accuracy: 49.20%
# Regularized test accuracy after additional training: 49.20%

# %% [markdown]
# ### Extended Training Results
#
# The extended training process stopped at epoch 28 and restored the model weights
# from epoch 23, which achieved the best validation loss of **1.8238** during this
# experiment.
#
# At epoch 23, the model reached a validation accuracy of **51.20%**. The learning
# rate was progressively reduced when the validation loss stopped improving,
# allowing the optimizer to make smaller weight updates.
#
# After extended training, the regularized model achieved a test accuracy of
# **49.20%**. This represents an improvement of **2.80 percentage points**
# compared with its test accuracy of **46.40%** after the initial 15 epochs,
# corresponding to **7 additional correctly classified test images**.
#
# The extended regularized model therefore reached the same test accuracy as the
# baseline model, which also achieved **49.20%**.
#
# These results confirm that the regularized model required more training because
# data augmentation and Dropout slowed down the learning process. EarlyStopping
# prevented unnecessary additional epochs, while ReduceLROnPlateau reduced the
# learning rate when validation performance stopped improving.
#
# Additional training allowed the regularized model to match the baseline test
# accuracy while maintaining substantially less overfitting. Therefore, the
# regularized model provides a better balance between learning the training data
# and generalizing to unseen images, although it did not surpass the baseline in
# test accuracy.

# %%
image_path = (
    "/content/drive/MyDrive/"
    "internet_images/"
    "spark_plug_internet"
)

# %%
import os

image_path = (
    "/content/drive/MyDrive/"
    "internet_images/"
    "spark_plug_internet.jpg"
)

print("Image found:", os.path.exists(image_path))
# Out:
# Image found: True

# %%
actual_class = "SPARK PLUG"

image = tf.keras.utils.load_img(
    image_path,
    target_size=IMAGE_SIZE
)

image_array = tf.keras.utils.img_to_array(
    image
)

image_array = image_array / 255.0

image_batch = tf.expand_dims(
    image_array,
    axis=0
)

print("Image shape:", image_array.shape)
print("Batch shape:", image_batch.shape)
# Out:
# Image shape: (224, 224, 3)
# Batch shape: (1, 224, 224, 3)

# %%
internet_model = baseline_model

probabilities = internet_model.predict(
    image_batch,
    verbose=0
)[0]

predicted_index = np.argmax(
    probabilities
)

predicted_class = class_names[
    predicted_index
]

confidence = probabilities[
    predicted_index
]

is_correct = predicted_class == actual_class

print(f"Actual class: {actual_class}")
print(f"Predicted class: {predicted_class}")
print(f"Confidence: {confidence * 100:.2f}%")
print(f"Correct prediction: {is_correct}")
# Out:
# Actual class: SPARK PLUG
# Predicted class: OXYGEN SENSOR
# Confidence: 39.21%
# Correct prediction: False

# %%
plt.figure(figsize=(7, 7))

plt.imshow(image)

plt.title(
    f"Actual: {actual_class}\n"
    f"Predicted: {predicted_class}\n"
    f"Confidence: {confidence * 100:.2f}%"
)

plt.axis("off")
plt.show()

# %%
top_5_indices = np.argsort(
    probabilities
)[-5:][::-1]

print("Top-5 predictions:")

for index in top_5_indices:
    print(
        f"{class_names[index]}: "
        f"{probabilities[index] * 100:.2f}%"
    )
# Out:
# Top-5 predictions:
# OXYGEN SENSOR: 39.21%
# SPARK PLUG: 35.30%
# THERMOSTAT: 19.47%
# PISTON: 5.69%
# OIL FILTER: 0.21%

# %% [markdown]
# ## Internet Image Evaluation
#
# A real-world image of a spark plug downloaded from the internet was evaluated
# using the baseline CNN.
#
# - **Actual class:** SPARK PLUG
# - **Predicted class:** OXYGEN SENSOR
# - **Prediction confidence:** 39.21%
# - **Correct prediction:** No
#
# The model incorrectly classified the image as `OXYGEN SENSOR`. However, the
# correct class, `SPARK PLUG`, appeared as the second most likely prediction with
# a probability of **35.30%**.
#
# The top predictions were:
#
# 1. `OXYGEN SENSOR` — 39.21%
# 2. `SPARK PLUG` — 35.30%
# 3. `THERMOSTAT` — 19.47%
# 4. `PISTON` — 5.69%
# 5. `OIL FILTER` — 0.21%
#
# The difference between the predicted class and the correct class was only
# **3.91 percentage points**. This indicates that the model identified several
# visual characteristics associated with spark plugs, although it assigned a
# slightly higher probability to the oxygen sensor class.
#
# Spark plugs and oxygen sensors can share visual characteristics such as metallic
# surfaces, cylindrical bodies, threaded sections, and narrow connector-like
# structures. These similarities may explain why the model had difficulty
# distinguishing between the two components.
#
# Differences between the internet image and the training images, including the
# background, lighting, object position, scale, and viewing angle, may also have
# affected the prediction.
#
# Therefore, the model did not correctly classify the external image. However,
# the correct class ranking second with a relatively high probability indicates
# partial recognition and uncertainty between two visually similar classes. This
# experiment shows that the baseline CNN still has difficulty generalizing to
# real-world images outside the original dataset distribution.
